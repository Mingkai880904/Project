# %%
import requests
import json
token = 'EAAEH3BlSOcgBAHOtpL4ZAX9mKGEZCekYGwZBd0ZBnb74ST10wFv5L2ilhC5QP3CeDhKDyXWbxUMxefxTrdFJYkibalcZCxNc9b8D7QIJxYRu8gVUW8kSTChvhShbc3WWl2UlTiZBAvhRfslkHzWDUUkQ6dQ56S5fr2HR6Cd8pRiM54gkSbpJgKgdrnaZCUPuPgZD'
res = requests.get('https://graph.facebook.com/v7.0/me/likes?access_token=%s'%(token))
jsondata = json.loads(res.text)
for athletes in jsondata['data']:
  print (athletes['name'])
# Out:
# GQ Taiwan
# 我是彰化人
# TechOrange 科技報橘
# 限時免費 iPhone 軟件集中營
# 熱血玩台南
# 這樣變型男
# Blue Moon::宇宙少女台灣站
# 우주소녀_ WJSN
# 爵士樂器
# WJSN 우주소녀-金知妍&李露多心動站
# MotoBuy 專業摩托情報
# 民視體育主播 陳建君的棒球島嶼
# 1theK (원더케이)
# Johntool-工具王阿璋
# Mr. Muscular - 你的網上健身百科全書
# 아이유는 아이가 아니에유
# 彰化市．Changhua City
# IU 李知恩 I&U愛나 台灣應援首站
# 아이유(IU)
# Po3C
# DailyView 網路溫度計
# 大學生 BIG Student
# 台南點 Tainan.
# 中國有嘻哈
# International Powerlifting Federation - IPF
